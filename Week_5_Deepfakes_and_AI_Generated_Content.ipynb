# %% [markdown]
# # Designing Interactions Around AI-Generated Content - Part I
#
# ---
#
#
# In this assignment you will consider the design of AI-generated voice and image technologies.

# %% [markdown]
# ## Part 1: AI-generated Voices (8 pts)
#
# ![Screen Shot 2021-11-12 at 1.07.58 PM.png](data:image/png;base64,...)
# [(link to tweet)](https://twitter.com/Memeulous/status/1359887922925867010?s=20)
#
# Many people dislike the voice-to-text feature on TikTok and report finding the voice annoying. Why do you think people dislike the AI-generated voice? What changes might result in a more positive interaction?

# %% [markdown]
# ### 1A: Articulate at least 3 criteria for good AI-generated voice interactions and provide justification. (3 pts)
# *Write your answers in the PDF you submit to Gradescope.*

# %% [markdown]
# ### 1B: Sketching Interactions (5 pts)
#
# [One of the readings](https://www.wired.com/story/deepfake-voices-help-trans-gamers/) for this week discussed the fact that gamers are sometimes "harassed when their voices don't match their gender identity." But there are also many other situations when gamers might find it useful or fun to have an AI generated voice. Design an interaction related to gaming and AI-generated voices.
#
# ### Create one sketch. Annotate your sketch with 1-3 sentences explaining how your design accomplishes particular user goals.  (5 pts per sketch)

# %% [markdown]
# ## Part 2: Generating Images (12 pts)
# [Dall-e 2](https://openai.com/dall-e-2/) is an AI tool for image generation. You can [create an account](https://labs.openai.com/auth/signup) and try it out yourself. Alternatively, you can try [craiyon](https://www.craiyon.com/) without creating an account, but note that the images will likely be of lower quality.
#
# ### 2A: Use Dalle-2 or a similar tool to create some AI-generated images. Include one generated image and the caption used to generate it for each of the following categories. (4 pts per image)
#
# ### We will have an art show / competition with the images you create, so have some fun with this!
#
#
# *   Most beautiful image
# *   Most surprising image
# *   Funniest image
#
#
# *Include the images in the PDF you submit to Gradescope. We will vote on the best images as a class!*
